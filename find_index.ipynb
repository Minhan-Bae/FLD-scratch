# %%
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image

# %%
data_path = pd.read_csv("/home/ubuntu/workspace/FLD-scratch/src/data/valid_df.csv",header=None).values.tolist()

# %%
idx = 10
data = data_path[0]

image = Image.open(data[2])
crop_img = image.crop((data[3]-100,
                       data[4]-100,
                       data[5]+100,
                       data[6]+100))

# %%
plt.figure(figsize=(11,11))
for i, landmark in enumerate(data[10:]):
    if i <21:
        x,y = eval(landmark[1:-1])
        plt.scatter(x,y)
        plt.annotate(i, (x,y))
        
plt.imshow(crop_img)

# %%
log_list = []

# %%
def displayandlog(text):
    global log_list
    print(text)
    log_list.append(text)

# %%
text = f"hello{2+4}"

# %%
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# %%
data_path = "/home/ubuntu/workspace/FLD-scratch/src/data/train_df.csv"
data_list = pd.read_csv(data_path,header=None).values.tolist()

# %%
data = data_list[0]

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x450>

# %%
import numpy as np
image = Image.open(data[2])
# crop_img = image.crop(
#     (data[3]-100,data[4]-100,data[5]+100,data[6]+100)
# )
plt.figure(figsize=(8,8))
list_x = []
list_y = []
for landmark in data[10:]:
    x,y = eval(landmark[1:-1])
    plt.scatter(x,y)
    list_x.append(x)
    list_y.append(y)
plt.imshow(image)

# %%
# for i in range(len(landmark_gt)):
minx = np.min(list_x)
miny = np.min(list_y)
maxx = np.max(list_x)
maxy = np.max(list_y)

# %%
minx, miny
# Out:
# (115, 111)

# %%
for x,y in zip(list_x, list_y):
    plt.scatter(x-minx, y-miny)
plt.imshow(image.crop((minx,miny,maxx,maxy)))
